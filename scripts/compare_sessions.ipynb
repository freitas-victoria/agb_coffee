# %%
import pandas as pd
from glob import glob

# %%
dados=pd.concat([pd.read_csv(f) for f in glob("/content/drive/MyDrive/gee_biomassa/[0-9]*_[0-9]*cafe2.csv")])

# %%
glob("/content/drive/MyDrive/gee_biomassa/[0-9]*_[0-9]*cafe2.csv")
# Out:
# ['/content/drive/MyDrive/gee_biomassa/2_502cafe2.csv',
#  '/content/drive/MyDrive/gee_biomassa/502_1002cafe2.csv']

# %%
dados_sort = dados[(dados['r2']>0) & (dados['r2']<=1)].sort_values('r2',ascending=False)

# %%
dados_sort.head(20)
# Out:
#      Unnamed: 0  session_id      r2
# 247         247         249  0.9256
# 184         184         186  0.8740
# 28           28         530  0.8510
# 116         116         118  0.8391
# 293         293         295  0.8309
# 223         223         225  0.8309
# 400         400         902  0.7776
# 408         408         410  0.7296
# 72           72         574  0.7121
# 416         416         918  0.7081
# 154         154         656  0.6842
# 24           24          26  0.6842
# 432         432         434  0.6456
# 304         304         806  0.6397
# 26           26          28  0.6355
# 355         355         857  0.6355
# 32           32          34  0.6310
# 444         444         946  0.6257
# 467         467         969  0.6113
# 320         320         322  0.6108

# %%
dados_sort.to_csv('/content/drive/MyDrive/gee_biomassa/ranking_cafe2_1502.csv')
